# %% [markdown]
# Instalar librerías

# %%
# %pip install pandas numpy
# Out:
# ...
#   Using cached pandas-3.0.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-3.0.2-cp312-cp312-win_amd64.whl (9.7 MB)
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.3 MB 2.1 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/12.3 MB 7.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.4/12.3 MB 8.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.2/12.3 MB 10.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/12.3 MB 12.5 MB/s eta 0:00:01
#    ------------ --------------------------- 3.8/12.3 MB 12.7 MB/s eta 0:00:01
#    -------------- ------------------------- 4.5/12.3 MB 13.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.3/12.3 MB 13.5 MB/s eta 0:00:01
#    -------------------- ------------------- 6.2/12.3 MB 14.1 MB/s eta 0:00:01
# ...
